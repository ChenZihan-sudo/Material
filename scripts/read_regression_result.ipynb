# %%
from args import *
from utils import *

plot_regression_result("GCN", "../results/1712671375624135", plotfilename="regression_figure")
# Out:
# -4.448057651519775 5.308639049530029
# MAE=  0.7512948890253749
